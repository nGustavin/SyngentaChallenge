# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
img = plt.imread("Syngenta.bmp")

# %%
plt.imshow(img)
plt.xticks([], [])
plt.yticks([], [])
# Out:
# ([], [])

# %%
plt.imshow(np.invert(img))
